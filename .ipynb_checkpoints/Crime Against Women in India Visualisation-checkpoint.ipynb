# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# This data is collated from https://data.gov.in. It has state-wise and district level data on the various crimes committed against women between 2001 to 2014. Some crimes that are included are Rape, Kidnapping and Abduction, Dowry Deaths etc.

# %%
## Reading files

raw_df = pd.read_csv("crimes_against_women_2001-2014.csv")

# %%
raw_df.head()
# Out:
#    Unnamed: 0        STATE/UT       DISTRICT  Year  Rape  \
# 0           0  ANDHRA PRADESH       ADILABAD  2001    50
# 1           1  ANDHRA PRADESH      ANANTAPUR  2001    23
# 2           2  ANDHRA PRADESH       CHITTOOR  2001    27
# 3           3  ANDHRA PRADESH       CUDDAPAH  2001    20
# 4           4  ANDHRA PRADESH  EAST GODAVARI  2001    23
#
#    Kidnapping and Abduction  Dowry Deaths  \
# 0                        30            16
# 1                        30             7
# 2                        34            14
# 3                        20            17
# 4                        26            12
#
#    Assault on women with intent to outrage her modesty  \
# 0                                                149
# 1                                                118
# 2                                                112
# 3                                                126
# 4                                                109
#
# ...

# %%
raw_df.drop(raw_df.columns[0],axis=1,inplace=True)
raw_df.shape
# Out:
# (10677, 10)

# %%
raw_df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
raw_df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
raw_df['DISTRICT'].unique()
# Out:
# array(['ADILABAD', 'ANANTAPUR', 'CHITTOOR', ..., 'Lakshadweep',
#        'Karaikal', 'Puducherry'], dtype=object)

# %%
raw_df['DISTRICT'].value_counts().sort_values(ascending=False)
# Out:
# TOTAL          408
# G.R.P.          49
# SOUTH           41
# NORTH           41
# WEST            39
#               ...
# SPUWAC           1
# Vigilance        1
# Lakshadweep      1
# Karaikal         1
# Puducherry       1
# Name: DISTRICT, Length: 1605, dtype: int64

# %%
raw_df['STATE/UT'].value_counts().sort_values(ascending=False)
# Out:
# UTTAR PRADESH     878
# MADHYA PRADESH    628
# MAHARASHTRA       552
# BIHAR             540
# TAMIL NADU        469
#                  ...
# A&N Islands         4
# Chandigarh          4
# D&N Haveli          4
# Lakshadweep         4
# A & N Islands       4
# Name: STATE/UT, Length: 72, dtype: int64

# %%
raw_df['STATE/UT'].unique()
# Out:
# array(['ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR',
#        'CHHATTISGARH', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH',
#        'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA',
#        'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM',
#        'NAGALAND', 'ODISHA', 'PUNJAB', 'RAJASTHAN', 'SIKKIM',
#        'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND',
#        'WEST BENGAL', 'A & N ISLANDS', 'CHANDIGARH', 'D & N HAVELI',
#        'DAMAN & DIU', 'DELHI', 'LAKSHADWEEP', 'PUDUCHERRY',
#        'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
# ...

# %%
raw_df['STATE/UT'] =  raw_df['STATE/UT'].str.lower()
raw_df['STATE/UT'].mask(raw_df['STATE/UT']=='a&n islands','a & n islands',inplace=True)
raw_df['STATE/UT'].mask(raw_df['STATE/UT']=='d&n haveli','d & n haveli',inplace=True)
raw_df['STATE/UT'].mask(raw_df['STATE/UT']=='delhi ut','delhi',inplace=True)

# %%
raw_df['STATE/UT'] = raw_df['STATE/UT'].str.title()
raw_df['DISTRICT'] = raw_df['DISTRICT'].str.title()

# %%
melted_df = pd.melt(raw_df,id_vars=['Year','STATE/UT','DISTRICT'], value_vars=['Rape', 'Kidnapping and Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls'],var_name='Crime', value_name='Case')

# %%
melted_df.head()
# Out:
#    Year        STATE/UT       DISTRICT Crime  Case
# 0  2001  Andhra Pradesh       Adilabad  Rape    50
# 1  2001  Andhra Pradesh      Anantapur  Rape    23
# 2  2001  Andhra Pradesh       Chittoor  Rape    27
# 3  2001  Andhra Pradesh       Cuddapah  Rape    20
# 4  2001  Andhra Pradesh  East Godavari  Rape    23

# %%
df = melted_df

# %%
df.head()
# Out:
#    Year        STATE/UT       DISTRICT Crime  Case
# 0  2001  Andhra Pradesh       Adilabad  Rape    50
# 1  2001  Andhra Pradesh      Anantapur  Rape    23
# 2  2001  Andhra Pradesh       Chittoor  Rape    27
# 3  2001  Andhra Pradesh       Cuddapah  Rape    20
# 4  2001  Andhra Pradesh  East Godavari  Rape    23

# %%
crime_summary = df[['Crime','Case']].groupby("Crime")['Case'].sum().reset_index()\
.sort_values(by='Case',ascending=True).reset_index(drop=True)

# %%
crime_summary['Percentage'] = round(crime_summary['Case']*100/np.sum(crime_summary['Case']),2)

# %%
crime_summary.replace({"Importation of Girls":"Trafficking","Insult to modesty of Women":"Insult to modesty" ,
                                       "Kidnapping and Abduction":"Kidnapping",
                                       "Assault on women with intent to outrage her modesty":"Assult",
                                       "Cruelty by Husband or his Relatives":"Cruelty by Husband"},inplace=True)

# %%
crime_summary
# Out:
#                 Crime     Case  Percentage
# 0         Trafficking     1872        0.04
# 1        Dowry Deaths   215480        4.05
# 2   Insult to modesty   292756        5.50
# 3                Rape   619158       11.63
# 4          Kidnapping   746198       14.02
# 5              Assult  1212258       22.78
# 6  Cruelty by Husband  2233888       41.98

# %%
fig ,ax = plt.subplots(1,2, figsize=(10, 5),constrained_layout = True)
hbars = ax[0].barh(crime_summary['Crime'],crime_summary['Case'])
hbars1 = ax[1].barh(crime_summary['Crime'],crime_summary['Percentage'])
ax[0].set_yticks([0,1,2,3,4,5,6],crime_summary['Crime'])

# ax.invert_yaxis()  # labels read top-to-bottom
ax[0].set_xlabel('Case')
ax[1].set_xlabel('Percentage')
# Label with specially formatted floats
ax[0].bar_label(hbars, fmt='%.f')
ax[1].bar_label(hbars1, fmt='%.f')
fig.suptitle("Number Of cases according to crime")
# ax.set_xlim(right=15)  # adjust xlim to fit labels
# fig.tight_layout(pad=5.0)
plt.show()

# %%
crime_summary = df[['Year','Crime','Case']].groupby(['Year','Crime'])['Case'].sum().reset_index()

# %%
crime_summary.head()
# Out:
#    Year                                              Crime   Case
# 0  2001  Assault on women with intent to outrage her mo...  68248
# 1  2001                Cruelty by Husband or his Relatives  98340
# 2  2001                                       Dowry Deaths  13702
# 3  2001                               Importation of Girls    228
# 4  2001                         Insult to modesty of Women  19492

# %%
crime_summary.replace({"Importation of Girls":"Trafficking","Insult to modesty of Women":"Insult to modesty" ,
                                       "Kidnapping and Abduction":"Kidnapping",
                                       "Assault on women with intent to outrage her modesty":"Assult",
                                       "Cruelty by Husband or his Relatives":"Cruelty by Husband"},inplace=True)

# %%
crime_summary.head()
# Out:
#    Year               Crime   Case
# 0  2001              Assult  68248
# 1  2001  Cruelty by Husband  98340
# 2  2001        Dowry Deaths  13702
# 3  2001         Trafficking    228
# 4  2001   Insult to modesty  19492

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data = crime_summary, x= 'Year',y='Case',hue='Crime')
plt.show()

# %%
temp_df = df.groupby(['Year'])['Case'].sum().reset_index()

# %%
temp_df.head()
# Out:
#    Year    Case
# 0  2001  261450
# 1  2002  262224
# 2  2003  262728
# 3  2004  287230
# 4  2005  287046

# %%
plt.style.use('default')
fig, ax = plt.subplots( figsize=(12, 5))
barh = ax.bar(temp_df['Year'],temp_df['Case'])
ax.set(xlabel='Year', ylabel='Number of Cases',
       title='Number of Crime on Women over the Year')
ax.bar_label(barh,fmt='%.f')
plt.show()

# %% [markdown]
# ### Rapes In India

# %%
rp_df = df[df['Crime']=='Rape']

# %%
df_heatmap = rp_df.groupby(['STATE/UT','Year'])['Case'].sum().reset_index()

# %%
df_heatmap.head()
# Out:
#         STATE/UT  Year  Case
# 0  A & N Islands  2001     6
# 1  A & N Islands  2002     4
# 2  A & N Islands  2003     4
# 3  A & N Islands  2004    20
# 4  A & N Islands  2005     8

# %%
df_heatmap = df_heatmap.pivot(index='STATE/UT',columns='Year',values='Case')

# %%
plt.figure(figsize=(7,5))
cmap_apalatte =sns.dark_palette("#69d", reverse=True, as_cmap=True) # sns.color_palette("crest", as_cmap=True) | sns.cubehelix_palette(as_cmap=True)
sns.heatmap(df_heatmap,cmap=cmap_apalatte) #cmap="crest"
plt.title("Rape Case in Inda")
plt.show()

# %%
rp_df.head()
# Out:
#    Year        STATE/UT       DISTRICT Crime  Case
# 0  2001  Andhra Pradesh       Adilabad  Rape    50
# 1  2001  Andhra Pradesh      Anantapur  Rape    23
# 2  2001  Andhra Pradesh       Chittoor  Rape    27
# 3  2001  Andhra Pradesh       Cuddapah  Rape    20
# 4  2001  Andhra Pradesh  East Godavari  Rape    23

# %%
rape_crimes = rp_df.groupby('Year')['Case'].sum().reset_index()

# %%
rape_crimes.head()
# Out:
#    Year   Case
# 0  2001  32150
# 1  2002  32746
# 2  2003  31694
# 3  2004  36466
# 4  2005  36718

# %%
fig ,ax = plt.subplots(figsize=(10,5))
barh = ax.bar(rape_crimes['Year'],rape_crimes['Case'])
ax.set(xlabel='Year', ylabel='Number of Rape Cases',
       title='Total Rape Cases (2001 - 2014)')
ax.bar_label(barh,fmt='%.f')
plt.show()

# %%
rape_crimes =rp_df[['STATE/UT','Case']].groupby(['STATE/UT']).sum().reset_index()

# %%
rape_crimes.sort_values(by='Case',ignore_index=True,inplace=True)

# %%
fig,ax = plt.subplots(figsize=(12,10))
barh = ax.barh(rape_crimes['STATE/UT'],rape_crimes['Case'])
ax.bar_label(barh,fmt='%.f')
ax.set(xlabel='Cases', ylabel='State',
       title='Rape cases in India per State')
plt.show()

# %% [markdown]
# ### Kidnapping and Abduction

# %%
df['Crime'].unique()
# Out:
# array(['Rape', 'Kidnapping and Abduction', 'Dowry Deaths',
#        'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women',
#        'Cruelty by Husband or his Relatives', 'Importation of Girls'],
#       dtype=object)

# %%
ka_df = df[df['Crime']=='Kidnapping and Abduction']

# %%
df_heatmap = ka_df[['Year','STATE/UT','Case']].groupby(['Year','STATE/UT'])['Case'].sum().reset_index()
df_heatmap = df_heatmap.pivot(index='STATE/UT',columns='Year',values='Case')

# %%
plt.figure(figsize=(7,5))
cmap_apalatte =sns.dark_palette("#69d", reverse=True, as_cmap=True) # sns.color_palette("crest", as_cmap=True) | sns.cubehelix_palette(as_cmap=True)
sns.heatmap(df_heatmap,cmap=cmap_apalatte) #cmap="crest"
plt.title("Kidnapping and Abduction Case in Inda")
plt.show()

# %%
ab_crimes = ka_df.groupby('Year')['Case'].sum().reset_index()

# %%
fig ,ax = plt.subplots(figsize=(10,5))
barh = ax.bar(ab_crimes['Year'],ab_crimes['Case'])
ax.set(xlabel='Year', ylabel='Number of Rape Cases',
       title='Total Kidnapping and Abduction Cases (2001 - 2014)')
ax.bar_label(barh,fmt='%.f')
plt.show()

# %%
ab_crimes =ka_df[['STATE/UT','Case']].groupby(['STATE/UT']).sum().reset_index()

# %%
ab_crimes.sort_values(by='Case',ignore_index=True,inplace=True)

# %%
fig,ax = plt.subplots(figsize=(12,10))
barh = ax.barh(ab_crimes['STATE/UT'],ab_crimes['Case'])
ax.bar_label(barh,fmt='%.f')
ax.set(xlabel='Cases', ylabel='State',
       title='Total Number of Kidnapping and Abduction cases Per State')
plt.show()

# %%
dd_df = df[df['Crime']=='Dowry Deaths']

# %%
df_heatmap = dd_df[['Year','STATE/UT','Case']].groupby(['Year','STATE/UT'])['Case'].sum().reset_index()
df_heatmap = df_heatmap.pivot(index='STATE/UT',columns='Year',values='Case')

# %%
plt.figure(figsize=(7,5))
cmap_apalatte =sns.dark_palette("#69d", reverse=True, as_cmap=True) # sns.color_palette("crest", as_cmap=True) | sns.cubehelix_palette(as_cmap=True)
sns.heatmap(df_heatmap,cmap=cmap_apalatte) #cmap="crest"
plt.title("Dowry Deaths Case in Inda")
plt.show()

# %%
dnd_crimes = dd_df.groupby('Year')['Case'].sum().reset_index()

# %%
fig ,ax = plt.subplots(figsize=(10,5))
barh = ax.bar(dnd_crimes['Year'],dnd_crimes['Case'])
ax.set(xlabel='Year', ylabel='Number of Rape Cases',
       title='Total Dowry Deaths Cases (2001 - 2014)')
ax.bar_label(barh,fmt='%.f')
plt.show()

# %%
dnd_crimes =dd_df[['STATE/UT','Case']].groupby(['STATE/UT']).sum().reset_index()
dnd_crimes.sort_values(by='Case',ignore_index=True,inplace=True)
fig,ax = plt.subplots(figsize=(12,10))
barh = ax.barh(dnd_crimes['STATE/UT'],dnd_crimes['Case'])
ax.bar_label(barh,fmt='%.f')
ax.set(xlabel='Cases', ylabel='State',
       title='Total Dowry Deaths and Abduction cases Per State')
plt.show()

# %%
crime_rate_13_14 = df.loc[df['Year'].isin([2013,2014]),['Year','STATE/UT','Case']].reset_index(drop=True)

# %%
crime_rate_13_14 = crime_rate_13_14.groupby(['Year','STATE/UT'])['Case'].sum().reset_index()

# %%
s = df.loc[df['Year']==2013,['STATE/UT']].values.flatten()
case_2013 = df.loc[df['Year']==2013,['Case']].values.flatten()
case_2014 = df.loc[df['Year']==2014,['Case']].values.flatten()
data = {
#     'Sate':s,
    '2013':case_2013,
    '2014':case_2014
}

crime_rate_13_14_df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [79], in <cell line: 10>()
#       3 case_2014 = df.loc[df['Year']==2014,['Case']].values.flatten()
#       4 data = {
#       5     'Sate':s,
#       6     '2013':case_2013,
#       7     '2014':case_2014
#       8 }
# ---> 10 crime_rate_13_14_df = pd.DataFrame(data)
#
# File ~\anaconda3\envs\machine_learning\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
# ...

# %%
crime_rate_13_14 = crime_rate_13_14.pivot(index='STATE/UT',columns='Year',values='Case')

# %%
df.loc[df['Year']==2013,['STATE/UT']].values.flatten()
# Out:
# array(['Andhra Pradesh', 'Andhra Pradesh', 'Andhra Pradesh', ...,
#        'Puducherry', 'Puducherry', 'Puducherry'], dtype=object)

# %%
crime_rate_13_14.loc['Year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\machine_learning\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\machine_learning\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\machine_learning\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# ...
